# %%
import requests
try:
    get_data = requests.get("https://fake-json-api.mock.beeceptor3.com/users2")
    try:
        get_data = requests.get("https://fake-json-api.mock.beeceptor3.com/users2")
        print(f"error in urls1")
    except:
        get_data = requests.get("https://fake-json-api.mock.beeceptor.com/users2")
        print(f"error in urls--")
except Exception as e:
    get_data = requests.get("https://fake-json-api.mock.beeceptor.com/users2")
    print(f"error in urls {e}")

finally:
    print(f"this is finally")
print(f"hello")
get_data.json()
print(f"h1")
# Out:
# error in urls HTTPSConnectionPool(host='fake-json-api.mock.beeceptor3.com', port=443): Max retries exceeded with url: /users2 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7e82c0cf75e0>: Failed to resolve 'fake-json-api.mock.beeceptor3.com' ([Errno -2] Name or service not known)"))
# this is finally
# hello
# h1

# %%
import requests
try:
    get_data= requests.get("https://fake-json")
    try:
        get_data = requests.get("https://fake-json-api.mock.beeceptor3.com/users2")
        print(f"error in urls1")
    except:
        get_data = requests.get("https://fake-json-api.mock.beeceptor.com/users2")
        print(f"error in urls--")
except Exception as e:
    get_data = requests.get("https://fake-json-api.mock.beeceptor.com/users2")
    print(f"error in urls {e}")

finally:
    print(f"this is finally")
print(f"hello")
get_data.json()
print(f"h1")

# %%
try:
    get_data = requests.get("https://fake-json-api.mock.beeceptor.com/users2",timeout=30)
finally:
    pass

# %%
retry = 4
for i in range(1,5):
    if i <2:
        try:
            get_data = requests.get("https://fake-json-api.mock.beeceptor1.com/users2",timeout=30)
            if get_data.status_code==200:
                break
        except:
            print(f"url is incorrect")
    else:
        get_data = requests.get("https://fake-json-api.mock.beeceptor.com/users2",timeout=30)
        if get_data.status_code==200:
                break
    
    print(f"get_data {get_data.status_code}")
# Out:
# url is incorrect
# get_data 200
