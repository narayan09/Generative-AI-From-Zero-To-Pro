# %%
#what is the difference between the concatenation & replication?
a="test"
b= "xyx"
print(a+b)
# Out:
# testxyx

# %%
#String Reversal & Palindrome Check
s= "narayan"

rev = ''
for s1 in s:
    rev = s1+rev
    
print(rev)
# Out:
# nayaran
